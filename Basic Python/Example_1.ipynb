# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

x = [1,2,3,4,5]
y = [10,20,30,40,50]
plt.plot (x,y)               # line grape
plt.bar (x,y)                # bar grape
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
