# %%
'''
Circle grap

'''
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

std = [10,20,35,20.34]                          # must be course
course = ["PHP","Flutter"",Java","C#","Notedjs"]

color = ["Red","Yellow","blue","white","cyan"]
exp = [0,0,0,0,0]
plt.pie (std,labels=course,autopct="%.2f%%",colors=color,shadow=True,startangle=45)

plt.show()
