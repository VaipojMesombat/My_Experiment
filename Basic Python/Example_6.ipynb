# %%
'''
Define maker suppport

'.' point
'o' xycle
'x' x marker
'+' plus
'*' star
's' square
'|' vline
'h' hline
'^' up
'v' down
'>' right
'<' left
'''
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

product1 = [10,20,30,40,50]
product2 = [12,15,20,17,34]
month = [1,2,3,4,5]

plt.plot (month,product2,color='m',marker='+')                    
plt.xlabel ("month")
plt.ylabel ("sale amount")         

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
