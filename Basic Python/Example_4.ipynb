# %%
'''
Save grape to fiel
'''
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

product1 = [10,20,30,40,50]
product2 = [12,15,20,17,34]
month = [1,2,3,4,5]

plt.plot (month,product1)               
plt.plot (month,product2)      
plt.xlabel ("month")
plt.ylabel ("sale amount")         
plt.savefig ("grape1.jpg")
plt.savefig ("grape1_trn.jpg",transparent=True)
plt.savefig ("grape2.png")
plt.savefig ("grape2_trn.png",transparent=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
